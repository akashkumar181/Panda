# %% [markdown]
# <a href="https://colab.research.google.com/github/akashkumar181/Panda/blob/main/PandaInsertandDelete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Insert

# %%
import pandas as pd

# %%
var = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]})
var
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
v=pd.DataFrame({"AA":[99,85,56,90],"BB":[110,330,440,990]})
v
# Out:
#    AA   BB
# 0  99  110
# 1  85  330
# 2  56  440
# 3  90  990

# %%
v.insert(2,"CC",v["AA"])
v
# Out:
#    AA   BB  CC
# 0  99  110  99
# 1  85  330  85
# 2  56  440  56
# 3  90  990  90

# %%
v.insert(1,"BB1",[45,98,45,2])
v
# Out:
#     BB  BB1  AA1  CC
# 0  110   45   45  99
# 1  330   98   98  85
# 2  440   45   45  56
# 3  990    2    2  90

# %%
v["DD"]=v["AA"][:3]#we are copying the element of AA int DD new column upto 3 places using slicing
v
# Out:
#    AA   BB  CC    DD
# 0  99  110  99  99.0
# 1  85  330  85  85.0
# 2  56  440  56  56.0
# 3  90  990  90   NaN

# %% [markdown]
# #Delete

# %%
x = v.pop("AA")
x
# Out:
# 0    99
# 1    85
# 2    56
# 3    90
# Name: AA, dtype: int64

# %%
del v["DD"]
v
# Out:
#     BB  CC
# 0  110  99
# 1  330  85
# 2  440  56
# 3  990  90
